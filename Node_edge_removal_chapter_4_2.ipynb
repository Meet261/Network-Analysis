# %%
## Box plot for Centrality measures after High Degree Node removal
## Random network

import networkx as nx
import matplotlib.pyplot as plt
import random

# Function to remove random nodes
def remove_high_degree_nodes(G, percent_nodes):
    num_nodes = int(G.number_of_nodes() * percent_nodes)
    sorted_nodes = sorted(G.degree(), key=lambda x: x[1], reverse=True)
    nodes_to_remove = [node[0] for node in sorted_nodes[:num_nodes]]
    G.remove_nodes_from(nodes_to_remove)


# Generate or load the network
G = nx.erdos_renyi_graph(n=100, p=0.2, seed = 1)

# Removal percentages
removal_percentages = [0.05, 0.1, 0.15 , 0.2, 0.25]

# Lists to store centrality differences
degree_differences = []
betweenness_differences = []
closeness_differences = []
eigenvector_differences = []


# Iterate over different edge removal percentages
for percent in removal_percentages:

    # To make a copy of the original network
    G_copy = G.copy()

    # Remove nodes
    remove_high_degree_nodes(G_copy, percent)

    # Calculate centrality measures before removal
    degree_centrality_before = nx.degree_centrality(G)
    betweenness_centrality_before = nx.betweenness_centrality(G)
    closeness_centrality_before = nx.closeness_centrality(G)
    eigenvector_centrality_before = nx.eigenvector_centrality(G)

    # Calculate centrality measures after removal
    degree_centrality_after = nx.degree_centrality(G_copy)
    betweenness_centrality_after = nx.betweenness_centrality(G_copy)
    closeness_centrality_after = nx.closeness_centrality(G_copy)
    eigenvector_centrality_after = nx.eigenvector_centrality(G_copy)

    # To Compute the Absolute difference of centrality measures after removal
    degree_difference = {node: abs(degree_centrality_before[node] - degree_centrality_after[node]) for node in G_copy.nodes()}
    betweenness_difference = {node: abs(betweenness_centrality_before[node] - betweenness_centrality_after[node]) for node in G_copy.nodes()}
    closeness_difference = {node: abs(closeness_centrality_before[node] - closeness_centrality_after[node]) for node in G_copy.nodes()}
    eigenvector_difference = {node: abs(eigenvector_centrality_before[node] - eigenvector_centrality_after[node]) for node in G_copy.nodes()}

    # Append centrality differences after removal to their respective lists
    degree_differences.append(list(degree_difference.values()))
    betweenness_differences.append(list(betweenness_difference.values()))
    closeness_differences.append(list(closeness_difference.values()))
    eigenvector_differences.append(list(eigenvector_difference.values()))


#Create subplots for removal
plt.figure(figsize=(8, 8))

plt.subplot(2, 2, 1)
plt.boxplot(degree_differences)
plt.xlabel('Node Removal Percentage')
plt.ylabel('Degree Centrality Difference')
plt.xticks(range(1, len(removal_percentages) + 1), [str(p) for p in removal_percentages])

plt.subplot(2, 2, 2)
plt.boxplot(betweenness_differences)
plt.xlabel('Node Removal Percentage')
plt.ylabel('Betweenness Centrality Difference')
plt.xticks(range(1, len(removal_percentages) + 1), [str(p) for p in removal_percentages])

plt.subplot(2, 2, 3)
plt.boxplot(closeness_differences)
plt.xlabel('Node Removal Percentage')
plt.ylabel('Closeness Centrality Difference')
plt.xticks(range(1, len(removal_percentages) + 1), [str(p) for p in removal_percentages])

plt.subplot(2, 2, 4)
plt.boxplot(eigenvector_differences)
plt.xlabel('Node Removal Percentage')
plt.ylabel('Eigenvector Centrality Difference')
plt.xticks(range(1, len(removal_percentages) + 1), [str(p) for p in removal_percentages])

plt.suptitle('Centrality Differences in a random network after High degree node Removal')
plt.tight_layout()

# To save the figure as a PDF
plt.savefig("random_network_high_degree_node_removal.pdf", format="pdf")

from google.colab import files
files.download("/content/random_network_high_degree_node_removal.pdf")
plt.show()

# %%
## Box plot for Centrality measures after Low degree Node removal
## Random network

import networkx as nx
import matplotlib.pyplot as plt
import random

# Function to remove random nodes
def remove_low_degree_nodes(G, percent_nodes):
    num_nodes = int(G.number_of_nodes() * percent_nodes)
    sorted_nodes = sorted(G.degree(), key=lambda x: x[1], reverse=False)
    nodes_to_remove = [node[0] for node in sorted_nodes[:num_nodes]]
    G.remove_nodes_from(nodes_to_remove)

# Generate the random network
G = nx.erdos_renyi_graph(n=100, p=0.2, seed = 1)

# Removal percentages
removal_percentages = [0.05, 0.1, 0.15 , 0.2, 0.25]

# Lists to store centrality differences
degree_differences = []
betweenness_differences = []
closeness_differences = []
eigenvector_differences = []


# Iterate over different removal percentages
for percent in removal_percentages:
    # To make a copy of the original network
    G_copy = G.copy()

    # Remove nodes
    remove_low_degree_nodes(G_copy, percent)

    # Calculate centrality measures before removal
    degree_centrality_before = nx.degree_centrality(G)
    betweenness_centrality_before = nx.betweenness_centrality(G)
    closeness_centrality_before = nx.closeness_centrality(G)
    eigenvector_centrality_before = nx.eigenvector_centrality(G)

    # Calculate centrality measures after removal
    degree_centrality_after = nx.degree_centrality(G_copy)
    betweenness_centrality_after = nx.betweenness_centrality(G_copy)
    closeness_centrality_after = nx.closeness_centrality(G_copy)
    eigenvector_centrality_after = nx.eigenvector_centrality(G_copy)

    # To Compute the Absolute difference of centrality measures after removal
    degree_difference = {node: abs(degree_centrality_before[node] - degree_centrality_after[node]) for node in G_copy.nodes()}
    betweenness_difference = {node: abs(betweenness_centrality_before[node] - betweenness_centrality_after[node]) for node in G_copy.nodes()}
    closeness_difference = {node: abs(closeness_centrality_before[node] - closeness_centrality_after[node]) for node in G_copy.nodes()}
    eigenvector_difference = {node: abs(eigenvector_centrality_before[node] - eigenvector_centrality_after[node]) for node in G_copy.nodes()}

    # Append centrality differences after removal to their respective lists
    degree_differences.append(list(degree_difference.values()))
    betweenness_differences.append(list(betweenness_difference.values()))
    closeness_differences.append(list(closeness_difference.values()))
    eigenvector_differences.append(list(eigenvector_difference.values()))


#Create subplots for node & edge removal
plt.figure(figsize=(8, 8))

plt.subplot(2, 2, 1)
plt.boxplot(degree_differences)
plt.xlabel('Node Removal Percentage')
plt.ylabel('Degree Centrality Difference')
plt.xticks(range(1, len(removal_percentages) + 1), [str(p) for p in removal_percentages])

plt.subplot(2, 2, 2)
plt.boxplot(betweenness_differences)
plt.xlabel('Node Removal Percentage')
plt.ylabel('Betweenness Centrality Difference')
plt.xticks(range(1, len(removal_percentages) + 1), [str(p) for p in removal_percentages])

plt.subplot(2, 2, 3)
plt.boxplot(closeness_differences)
plt.xlabel('Node Removal Percentage')
plt.ylabel('Closeness Centrality Difference')
plt.xticks(range(1, len(removal_percentages) + 1), [str(p) for p in removal_percentages])

plt.subplot(2, 2, 4)
plt.boxplot(eigenvector_differences)
plt.xlabel('Node Removal Percentage')
plt.ylabel('Eigenvector Centrality Difference')
plt.xticks(range(1, len(removal_percentages) + 1), [str(p) for p in removal_percentages])

plt.suptitle('Centrality Differences in a random network after Low degree node Removal')
plt.tight_layout()
# To save the figure as a PDF
plt.savefig("random_network_low_degree_node_removal.pdf", format="pdf")

from google.colab import files
files.download("/content/random_network_low_degree_node_removal.pdf")
plt.show()

# %%
## Box plot for Centrality measures after Random Node removal
## Random network

import networkx as nx
import matplotlib.pyplot as plt
import random

# Function to remove random nodes
def remove_random_nodes(G, percent_nodes):
    num_nodes = int(G.number_of_nodes() * percent_nodes)
    nodes_to_remove = random.sample(list(G.nodes()), num_nodes)
    G.remove_nodes_from(nodes_to_remove)

# Generate the random network
G = nx.erdos_renyi_graph(n=100, p=0.2,  seed = 1)

# List of edge removal percentages
removal_percentages = [0.05, 0.1, 0.15 , 0.2, 0.25]

# Lists to store centrality differences
degree_differences = []
betweenness_differences = []
closeness_differences = []
eigenvector_differences = []


# Iterate over different removal percentages
for percent in removal_percentages:
    # To make a copy of the original network
    G_copy = G.copy()

    # Remove nodes
    remove_random_nodes(G_copy, percent)

    # Calculate centrality measures before removal
    degree_centrality_before = nx.degree_centrality(G)
    betweenness_centrality_before = nx.betweenness_centrality(G)
    closeness_centrality_before = nx.closeness_centrality(G)
    eigenvector_centrality_before = nx.eigenvector_centrality(G)

    # Calculate centrality measures after removal
    degree_centrality_after = nx.degree_centrality(G_copy)
    betweenness_centrality_after = nx.betweenness_centrality(G_copy)
    closeness_centrality_after = nx.closeness_centrality(G_copy)
    eigenvector_centrality_after = nx.eigenvector_centrality(G_copy)

    # To Compute the Absolute difference of centrality measures after removal
    degree_difference = {node: abs(degree_centrality_before[node] - degree_centrality_after[node]) for node in G_copy.nodes()}
    betweenness_difference = {node: abs(betweenness_centrality_before[node] - betweenness_centrality_after[node]) for node in G_copy.nodes()}
    closeness_difference = {node: abs(closeness_centrality_before[node] - closeness_centrality_after[node]) for node in G_copy.nodes()}
    eigenvector_difference = {node: abs(eigenvector_centrality_before[node] - eigenvector_centrality_after[node]) for node in G_copy.nodes()}

    # Append centrality differences after removal to their respective lists
    degree_differences.append(list(degree_difference.values()))
    betweenness_differences.append(list(betweenness_difference.values()))
    closeness_differences.append(list(closeness_difference.values()))
    eigenvector_differences.append(list(eigenvector_difference.values()))


#Create subplots for node & edge removal
plt.figure(figsize=(8, 8))

plt.subplot(2, 2, 1)
plt.boxplot(degree_differences)
plt.xlabel('Node Removal Percentage')
plt.ylabel('Degree Centrality Difference')
plt.xticks(range(1, len(removal_percentages) + 1), [str(p) for p in removal_percentages])

plt.subplot(2, 2, 2)
plt.boxplot(betweenness_differences)
plt.xlabel('Node Removal Percentage')
plt.ylabel('Betweenness Centrality Difference')
plt.xticks(range(1, len(removal_percentages) + 1), [str(p) for p in removal_percentages])

plt.subplot(2, 2, 3)
plt.boxplot(closeness_differences)
plt.xlabel('Node Removal Percentage')
plt.ylabel('Closeness Centrality Difference')
plt.xticks(range(1, len(removal_percentages) + 1), [str(p) for p in removal_percentages])

plt.subplot(2, 2, 4)
plt.boxplot(eigenvector_differences)
plt.xlabel('Node Removal Percentage')
plt.ylabel('Eigenvector Centrality Difference')
plt.xticks(range(1, len(removal_percentages) + 1), [str(p) for p in removal_percentages])

plt.suptitle('Centrality Differences in a random network after Random node Removal')
plt.tight_layout()
# To save the figure as a PDF
plt.savefig("random_network_random_node_removal.pdf", format="pdf")

from google.colab import files
files.download("/content/random_network_random_node_removal.pdf")
plt.show()

# %%
## Box plot for Centrality measures after High Degree Node removal
## Scale-free network
import networkx as nx
import matplotlib.pyplot as plt
import random

# Function to remove random nodes
def remove_high_degree_nodes(G, percent_nodes):
    num_nodes = int(G.number_of_nodes() * percent_nodes)
    sorted_nodes = sorted(G.degree(), key=lambda x: x[1], reverse=True)
    nodes_to_remove = [node[0] for node in sorted_nodes[:num_nodes]]
    G.remove_nodes_from(nodes_to_remove)

# Create a scale-free network

G = nx.barabasi_albert_graph(n = 100, m = 2, seed=1)

# Removal percentages
removal_percentages = [0.05, 0.1, 0.15 , 0.2, 0.25]

# Lists to store centrality differences
degree_differences = []
betweenness_differences = []
closeness_differences = []
eigenvector_differences = []


# Iterate over different removal percentages
for percent in removal_percentages:
    # To make a copy of the original network
    G_copy = G.copy()

    # Remove nodes
    remove_high_degree_nodes(G_copy, percent)

   # Calculate centrality measures before removal
    degree_centrality_before = nx.degree_centrality(G)
    betweenness_centrality_before = nx.betweenness_centrality(G)
    closeness_centrality_before = nx.closeness_centrality(G)
    eigenvector_centrality_before = nx.eigenvector_centrality(G)

    # Calculate centrality measures after removal
    degree_centrality_after = nx.degree_centrality(G_copy)
    betweenness_centrality_after = nx.betweenness_centrality(G_copy)
    closeness_centrality_after = nx.closeness_centrality(G_copy)
    eigenvector_centrality_after = nx.eigenvector_centrality(G_copy)

    # To Compute the Absolute difference of centrality measures after removal
    degree_difference = {node: abs(degree_centrality_before[node] - degree_centrality_after[node]) for node in G_copy.nodes()}
    betweenness_difference = {node: abs(betweenness_centrality_before[node] - betweenness_centrality_after[node]) for node in G_copy.nodes()}
    closeness_difference = {node: abs(closeness_centrality_before[node] - closeness_centrality_after[node]) for node in G_copy.nodes()}
    eigenvector_difference = {node: abs(eigenvector_centrality_before[node] - eigenvector_centrality_after[node]) for node in G_copy.nodes()}

    # Append centrality differences after removal to their respective lists
    degree_differences.append(list(degree_difference.values()))
    betweenness_differences.append(list(betweenness_difference.values()))
    closeness_differences.append(list(closeness_difference.values()))
    eigenvector_differences.append(list(eigenvector_difference.values()))


#Create subplots for node & edge removal
plt.figure(figsize=(8, 8))

plt.subplot(2, 2, 1)
plt.boxplot(degree_differences)
plt.xlabel('Node Removal Percentage')
plt.ylabel('Degree Centrality Difference')
plt.xticks(range(1, len(removal_percentages) + 1), [str(p) for p in removal_percentages])

plt.subplot(2, 2, 2)
plt.boxplot(betweenness_differences)
plt.xlabel('Node Removal Percentage')
plt.ylabel('Betweenness Centrality Difference')
plt.xticks(range(1, len(removal_percentages) + 1), [str(p) for p in removal_percentages])

plt.subplot(2, 2, 3)
plt.boxplot(closeness_differences)
plt.xlabel('Node Removal Percentage')
plt.ylabel('Closeness Centrality Difference')
plt.xticks(range(1, len(removal_percentages) + 1), [str(p) for p in removal_percentages])

plt.subplot(2, 2, 4)
plt.boxplot(eigenvector_differences)
plt.xlabel('Node Removal Percentage')
plt.ylabel('Eigenvector Centrality Difference')
plt.xticks(range(1, len(removal_percentages) + 1), [str(p) for p in removal_percentages])

plt.suptitle('Centrality Differences in a scale-free network after High degree node Removal')
plt.tight_layout()
# TO save the figure as a PDF
plt.savefig("scale_free_network_high_degree_node_removal.pdf", format="pdf")

from google.colab import files
files.download("/content/scale_free_network_high_degree_node_removal.pdf")
plt.show()

print(degree_difference)
# Out:
# {9: 0.020202020202020204, 14: 0.01678951678951679, 18: 0.020202020202020204, 19: 0.01678951678951679, 21: 0.01678951678951679, 22: 0.030303030303030304, 23: 0.0032760032760032753, 26: 0.01678951678951679, 29: 0.020202020202020204, 30: 0.01678951678951679, 31: 0.020202020202020204, 35: 0.020202020202020204, 36: 0.013377013377013379, 37: 0.013377013377013379, 38: 0.01678951678951679, 40: 0.01678951678951679, 41: 0.01678951678951679, 42: 0.020202020202020204, 43: 0.020202020202020204, 44: 0.020202020202020204, 45: 0.0032760032760032753, 46: 0.020202020202020204, 47: 0.01678951678951679, 48: 0.013377013377013379, 49: 0.020202020202020204, 50: 0.006825006825006825, 51: 0.01678951678951679, 52: 0.01678951678951679, 53: 0.0032760032760032753, 54: 0.013377013377013379, 55: 0.01678951678951679, 56: 0.0032760032760032753, 57: 0.0066885066885066895, 58: 0.00013650013650013532, 59: 0.010237510237510239, 60: 0.0032760032760032753, 61: 0.0066885066885066895, 62: 0.013377013377013379, 63: 0.0102375
# ...

# %%
## Box plot for Centrality measures after Low Degree Node removal
## Scale-free network
import networkx as nx
import matplotlib.pyplot as plt
import random

# Function to remove random nodes
def remove_low_degree_nodes(G, percent_nodes):
    num_nodes = int(G.number_of_nodes() * percent_nodes)
    sorted_nodes = sorted(G.degree(), key=lambda x: x[1], reverse=False)
    nodes_to_remove = [node[0] for node in sorted_nodes[:num_nodes]]
    G.remove_nodes_from(nodes_to_remove)

# Create a scale-free network

G = nx.barabasi_albert_graph(n = 100, m = 2, seed=1)

# Removal percentages
removal_percentages = [0.05, 0.1, 0.15 , 0.2, 0.25]

# Lists to store centrality differences
degree_differences = []
betweenness_differences = []
closeness_differences = []
eigenvector_differences = []


# Iterate over different edge removal percentages
for percent in removal_percentages:
    # To make a copy of the original network
    G_copy = G.copy()

    # Remove nodes
    remove_low_degree_nodes(G_copy, percent)

    # Calculate centrality measures before removal
    degree_centrality_before = nx.degree_centrality(G)
    betweenness_centrality_before = nx.betweenness_centrality(G)
    closeness_centrality_before = nx.closeness_centrality(G)
    eigenvector_centrality_before = nx.eigenvector_centrality(G)

    # Calculate centrality measures after removal
    degree_centrality_after = nx.degree_centrality(G_copy)
    betweenness_centrality_after = nx.betweenness_centrality(G_copy)
    closeness_centrality_after = nx.closeness_centrality(G_copy)
    eigenvector_centrality_after = nx.eigenvector_centrality(G_copy)

    # To Compute the Absolute difference of centrality measures after removal
    degree_difference = {node: abs(degree_centrality_before[node] - degree_centrality_after[node]) for node in G_copy.nodes()}
    betweenness_difference = {node: abs(betweenness_centrality_before[node] - betweenness_centrality_after[node]) for node in G_copy.nodes()}
    closeness_difference = {node: abs(closeness_centrality_before[node] - closeness_centrality_after[node]) for node in G_copy.nodes()}
    eigenvector_difference = {node: abs(eigenvector_centrality_before[node] - eigenvector_centrality_after[node]) for node in G_copy.nodes()}

    # Append centrality differences after removal to their respective lists
    degree_differences.append(list(degree_difference.values()))
    betweenness_differences.append(list(betweenness_difference.values()))
    closeness_differences.append(list(closeness_difference.values()))
    eigenvector_differences.append(list(eigenvector_difference.values()))


#Create subplots for node & edge removal
plt.figure(figsize=(8, 8))

plt.subplot(2, 2, 1)
plt.boxplot(degree_differences)
plt.xlabel('Node Removal Percentage')
plt.ylabel('Degree Centrality Difference')
plt.xticks(range(1, len(removal_percentages) + 1), [str(p) for p in removal_percentages])

plt.subplot(2, 2, 2)
plt.boxplot(betweenness_differences)
plt.xlabel('Node Removal Percentage')
plt.ylabel('Betweenness Centrality Difference')
plt.xticks(range(1, len(removal_percentages) + 1), [str(p) for p in removal_percentages])

plt.subplot(2, 2, 3)
plt.boxplot(closeness_differences)
plt.xlabel('Node Removal Percentage')
plt.ylabel('Closeness Centrality Difference')
plt.xticks(range(1, len(removal_percentages) + 1), [str(p) for p in removal_percentages])

plt.subplot(2, 2, 4)
plt.boxplot(eigenvector_differences)
plt.xlabel('Node Removal Percentage')
plt.ylabel('Eigenvector Centrality Difference')
plt.xticks(range(1, len(removal_percentages) + 1), [str(p) for p in removal_percentages])

plt.suptitle('Centrality Differences in a scale-free network after Low degree node Removal')
plt.tight_layout()
# To save the figure as a PDF
plt.savefig("scale_free_network_low_degree_node_removal.pdf", format="pdf")

from google.colab import files
files.download("/content/scale_free_network_low_degree_node_removal.pdf")
plt.show()

print(degree_difference)
# Out:
# {0: 0.03112203112203113, 1: 0.013786513786513785, 2: 0.009964509964509968, 3: 0.004231504231504257, 4: 0.02388752388752388, 5: 0.02757302757302757, 6: 0.006961506961506964, 7: 0.01706251706251706, 8: 0.030030030030030033, 10: 0.01365001365001365, 11: 0.003549003549003546, 12: 0.0030030030030030047, 13: 0.00013650013650013532, 14: 0.0032760032760032753, 15: 0.01365001365001365, 16: 0.010374010374010367, 17: 0.020475020475020478, 19: 0.010237510237510239, 20: 0.006961506961506964, 21: 0.010237510237510239, 22: 0.010237510237510239, 23: 0.010237510237510239, 24: 0.009964509964509968, 25: 0.0038220038220038166, 26: 0.010237510237510239, 27: 0.003139503139503147, 28: 0.003549003549003546, 30: 0.010237510237510239, 32: 0.013377013377013379, 33: 0.003549003549003546, 34: 0.00027300027300027063, 36: 0.00013650013650013532, 37: 0.01365001365001365, 38: 0.010237510237510239, 39: 0.003549003549003546, 40: 0.010237510237510239, 41: 0.010237510237510239, 45: 0.010237510237510239, 47: 0.0102375102
# ...

# %%
## Box plot for Centrality measures after Random Node removal
## Scale-free network
import networkx as nx
import matplotlib.pyplot as plt
import random

# Function to remove random nodes
def remove_random_nodes(G, percent_nodes):
    num_nodes = int(G.number_of_nodes() * percent_nodes)
    nodes_to_remove = random.sample(list(G.nodes()), num_nodes)
    G.remove_nodes_from(nodes_to_remove)

# Create a scale-free network

G = nx.barabasi_albert_graph(n = 100, m = 2, seed=1)

# Removal percentages
removal_percentages = [0.05, 0.1, 0.15 , 0.2, 0.25]

# Lists to store centrality differences
degree_differences = []
betweenness_differences = []
closeness_differences = []
eigenvector_differences = []


# Iterate over different removal percentages
for percent in removal_percentages:
    # To make a copy of the original network
    G_copy = G.copy()

    # Remove nodes
    remove_random_nodes(G_copy, percent)

   # Calculate centrality measures before removal
    degree_centrality_before = nx.degree_centrality(G)
    betweenness_centrality_before = nx.betweenness_centrality(G)
    closeness_centrality_before = nx.closeness_centrality(G)
    eigenvector_centrality_before = nx.eigenvector_centrality(G)

    # Calculate centrality measures after removal
    degree_centrality_after = nx.degree_centrality(G_copy)
    betweenness_centrality_after = nx.betweenness_centrality(G_copy)
    closeness_centrality_after = nx.closeness_centrality(G_copy)
    eigenvector_centrality_after = nx.eigenvector_centrality(G_copy)

    # To Compute the Absolute difference of centrality measures after removal
    degree_difference = {node: abs(degree_centrality_before[node] - degree_centrality_after[node]) for node in G_copy.nodes()}
    betweenness_difference = {node: abs(betweenness_centrality_before[node] - betweenness_centrality_after[node]) for node in G_copy.nodes()}
    closeness_difference = {node: abs(closeness_centrality_before[node] - closeness_centrality_after[node]) for node in G_copy.nodes()}
    eigenvector_difference = {node: abs(eigenvector_centrality_before[node] - eigenvector_centrality_after[node]) for node in G_copy.nodes()}

    # Append centrality differences after removal to their respective lists
    degree_differences.append(list(degree_difference.values()))
    betweenness_differences.append(list(betweenness_difference.values()))
    closeness_differences.append(list(closeness_difference.values()))
    eigenvector_differences.append(list(eigenvector_difference.values()))


#Create subplots for node & edge removal
plt.figure(figsize=(8, 8))

plt.subplot(2, 2, 1)
plt.boxplot(degree_differences)
plt.xlabel('Node Removal Percentage')
plt.ylabel('Degree Centrality Difference')
plt.xticks(range(1, len(removal_percentages) + 1), [str(p) for p in removal_percentages])

plt.subplot(2, 2, 2)
plt.boxplot(betweenness_differences)
plt.xlabel('Node Removal Percentage')
plt.ylabel('Betweenness Centrality Difference')
plt.xticks(range(1, len(removal_percentages) + 1), [str(p) for p in removal_percentages])

plt.subplot(2, 2, 3)
plt.boxplot(closeness_differences)
plt.xlabel('Node Removal Percentage')
plt.ylabel('Closeness Centrality Difference')
plt.xticks(range(1, len(removal_percentages) + 1), [str(p) for p in removal_percentages])

plt.subplot(2, 2, 4)
plt.boxplot(eigenvector_differences)
plt.xlabel('Node Removal Percentage')
plt.ylabel('Eigenvector Centrality Difference')
plt.xticks(range(1, len(removal_percentages) + 1), [str(p) for p in removal_percentages])

plt.suptitle('Centrality Differences in a scale-free network after Random node Removal')
plt.tight_layout()
# To save the figure as a PDF
plt.savefig("scale_free_network_random_node_removal.pdf", format="pdf")

from google.colab import files
files.download("/content/scale_free_network_random_node_removal.pdf")
plt.show()

print(degree_difference)
# Out:
# {0: 0.03112203112203113, 1: 0.0273000273000273, 2: 0.01706251706251706, 3: 0.004231504231504257, 4: 0.01665301665301666, 6: 0.006552006552006551, 7: 0.009964509964509968, 9: 0.006825006825006825, 10: 0.01365001365001365, 12: 0.01051051051051051, 13: 0.013377013377013379, 14: 0.0032760032760032753, 15: 0.013377013377013379, 16: 0.010374010374010367, 18: 0.0066885066885066895, 21: 0.0032760032760032753, 22: 0.0032760032760032753, 24: 0.01706251706251706, 25: 0.009691509691509698, 26: 0.0032760032760032753, 28: 0.01706251706251706, 29: 0.0066885066885066895, 31: 0.006825006825006825, 32: 0.00013650013650013532, 33: 0.003549003549003546, 34: 0.013786513786513785, 35: 0.006825006825006825, 36: 0.04040404040404041, 37: 0.013377013377013379, 38: 0.0032760032760032753, 40: 0.0032760032760032753, 41: 0.01678951678951679, 42: 0.006825006825006825, 43: 0.0066885066885066895, 46: 0.020202020202020204, 47: 0.01678951678951679, 48: 0.01365001365001365, 49: 0.006825006825006825, 51: 0.0032760032760
# ...

# %%
## Box plot for Centrality measures after High Degree Node removal
## Small-world network

import networkx as nx
import matplotlib.pyplot as plt
import random

# Function to remove random nodes
def remove_high_degree_nodes(G, percent_nodes):
    num_nodes = int(G.number_of_nodes() * percent_nodes)
    sorted_nodes = sorted(G.degree(), key=lambda x: x[1], reverse=True)
    nodes_to_remove = [node[0] for node in sorted_nodes[:num_nodes]]
    G.remove_nodes_from(nodes_to_remove)

# Create a Small-world network
G = nx.watts_strogatz_graph(n =100, k = 4, p =0.2,seed =1)

# Removal percentages
removal_percentages = [0.05, 0.1, 0.15 , 0.2, 0.25]

# Lists to store centrality differences
degree_differences = []
betweenness_differences = []
closeness_differences = []
eigenvector_differences = []


# Iterate over different removal percentages
for percent in removal_percentages:
    # To make a copy of the original network
    G_copy = G.copy()

    # Remove nodes
    remove_high_degree_nodes(G_copy, percent)

    # Calculate centrality measures before removal
    degree_centrality_before = nx.degree_centrality(G)
    betweenness_centrality_before = nx.betweenness_centrality(G)
    closeness_centrality_before = nx.closeness_centrality(G)
    eigenvector_centrality_before = nx.eigenvector_centrality(G)

    # Calculate centrality measures after removal
    degree_centrality_after = nx.degree_centrality(G_copy)
    betweenness_centrality_after = nx.betweenness_centrality(G_copy)
    closeness_centrality_after = nx.closeness_centrality(G_copy)
    eigenvector_centrality_after = nx.eigenvector_centrality(G_copy)

    # To Compute the Absolute difference of centrality measures after removal
    degree_difference = {node: abs(degree_centrality_before[node] - degree_centrality_after[node]) for node in G_copy.nodes()}
    betweenness_difference = {node: abs(betweenness_centrality_before[node] - betweenness_centrality_after[node]) for node in G_copy.nodes()}
    closeness_difference = {node: abs(closeness_centrality_before[node] - closeness_centrality_after[node]) for node in G_copy.nodes()}
    eigenvector_difference = {node: abs(eigenvector_centrality_before[node] - eigenvector_centrality_after[node]) for node in G_copy.nodes()}

    # Append centrality differences after removal to their respective lists
    degree_differences.append(list(degree_difference.values()))
    betweenness_differences.append(list(betweenness_difference.values()))
    closeness_differences.append(list(closeness_difference.values()))
    eigenvector_differences.append(list(eigenvector_difference.values()))


#Create subplots for node & edge removal
plt.figure(figsize=(8, 8))

plt.subplot(2, 2, 1)
plt.boxplot(degree_differences)
plt.xlabel('Node Removal Percentage')
plt.ylabel('Degree Centrality Difference')
plt.xticks(range(1, len(removal_percentages) + 1), [str(p) for p in removal_percentages])

plt.subplot(2, 2, 2)
plt.boxplot(betweenness_differences)
plt.xlabel('Node Removal Percentage')
plt.ylabel('Betweenness Centrality Difference')
plt.xticks(range(1, len(removal_percentages) + 1), [str(p) for p in removal_percentages])

plt.subplot(2, 2, 3)
plt.boxplot(closeness_differences)
plt.xlabel('Node Removal Percentage')
plt.ylabel('Closeness Centrality Difference')
plt.xticks(range(1, len(removal_percentages) + 1), [str(p) for p in removal_percentages])

plt.subplot(2, 2, 4)
plt.boxplot(eigenvector_differences)
plt.xlabel('Node Removal Percentage')
plt.ylabel('Eigenvector Centrality Difference')
plt.xticks(range(1, len(removal_percentages) + 1), [str(p) for p in removal_percentages])

plt.suptitle('Centrality Differences in a small-world network after High degree node Removal')
plt.tight_layout()
# To save the figure as a PDF
plt.savefig("small_world_network_high_degree_node_removal.pdf", format="pdf")

from google.colab import files
files.download("/content/small_world_network_high_degree_node_removal.pdf")


plt.show()

# %%
## Box plot for Centrality measures after Low Degree Node removal
## Small-world network

import networkx as nx
import matplotlib.pyplot as plt
import random

# Function to remove random nodes
def remove_low_degree_nodes(G, percent_nodes):
    num_nodes = int(G.number_of_nodes() * percent_nodes)
    sorted_nodes = sorted(G.degree(), key=lambda x: x[1], reverse=False)
    nodes_to_remove = [node[0] for node in sorted_nodes[:num_nodes]]
    G.remove_nodes_from(nodes_to_remove)

# Create a Small-world network
G = nx.watts_strogatz_graph(n =100, k = 4, p =0.2,seed =1)

# Removal percentages
removal_percentages = [0.05, 0.1, 0.15 , 0.2, 0.25]

# Lists to store centrality differences
degree_differences = []
betweenness_differences = []
closeness_differences = []
eigenvector_differences = []


# Iterate over different removal percentages
for percent in removal_percentages:
    # To make a copy of the original network
    G_copy = G.copy()

    # Remove nodes
    remove_low_degree_nodes(G_copy, percent)

    # Calculate centrality measures before removal
    degree_centrality_before = nx.degree_centrality(G)
    betweenness_centrality_before = nx.betweenness_centrality(G)
    closeness_centrality_before = nx.closeness_centrality(G)
    eigenvector_centrality_before = nx.eigenvector_centrality(G)

    # Calculate centrality measures after removal
    degree_centrality_after = nx.degree_centrality(G_copy)
    betweenness_centrality_after = nx.betweenness_centrality(G_copy)
    closeness_centrality_after = nx.closeness_centrality(G_copy)
    eigenvector_centrality_after = nx.eigenvector_centrality(G_copy)

    # To Compute the Absolute difference of centrality measures after removal
    degree_difference = {node: abs(degree_centrality_before[node] - degree_centrality_after[node]) for node in G_copy.nodes()}
    betweenness_difference = {node: abs(betweenness_centrality_before[node] - betweenness_centrality_after[node]) for node in G_copy.nodes()}
    closeness_difference = {node: abs(closeness_centrality_before[node] - closeness_centrality_after[node]) for node in G_copy.nodes()}
    eigenvector_difference = {node: abs(eigenvector_centrality_before[node] - eigenvector_centrality_after[node]) for node in G_copy.nodes()}

    # Append centrality differences after removal to their respective lists
    degree_differences.append(list(degree_difference.values()))
    betweenness_differences.append(list(betweenness_difference.values()))
    closeness_differences.append(list(closeness_difference.values()))
    eigenvector_differences.append(list(eigenvector_difference.values()))


#Create subplots for node & edge removal
plt.figure(figsize=(8, 8))

plt.subplot(2, 2, 1)
plt.boxplot(degree_differences)
plt.xlabel('Node Removal Percentage')
plt.ylabel('Degree Centrality Difference')
plt.xticks(range(1, len(removal_percentages) + 1), [str(p) for p in removal_percentages])

plt.subplot(2, 2, 2)
plt.boxplot(betweenness_differences)
plt.xlabel('Node Removal Percentage')
plt.ylabel('Betweenness Centrality Difference')
plt.xticks(range(1, len(removal_percentages) + 1), [str(p) for p in removal_percentages])

plt.subplot(2, 2, 3)
plt.boxplot(closeness_differences)
plt.xlabel('Node Removal Percentage')
plt.ylabel('Closeness Centrality Difference')
plt.xticks(range(1, len(removal_percentages) + 1), [str(p) for p in removal_percentages])

plt.subplot(2, 2, 4)
plt.boxplot(eigenvector_differences)
plt.xlabel('Node Removal Percentage')
plt.ylabel('Eigenvector Centrality Difference')
plt.xticks(range(1, len(removal_percentages) + 1), [str(p) for p in removal_percentages])

plt.suptitle('Centrality Differences in a small-world network after Low degree node Removal')
plt.tight_layout()
# To save the figure as a PDF
plt.savefig("small_world_network_low_degree_node_removal.pdf", format="pdf")

from google.colab import files
files.download("/content/small_world_network_low_degree_node_removal.pdf")
plt.show()

# %%
## Box plot for Centrality measures after Random Node removal
## Small-world network

import networkx as nx
import matplotlib.pyplot as plt
import random

# Function to remove random nodes
def remove_random_nodes(G, percent_nodes):
    num_nodes = int(G.number_of_nodes() * percent_nodes)
    nodes_to_remove = random.sample(list(G.nodes()), num_nodes)
    G.remove_nodes_from(nodes_to_remove)

# Create a small-world network
G = nx.watts_strogatz_graph(n =100, k = 4, p =0.2,seed =1)

# Removal percentages
removal_percentages = [0.05, 0.1, 0.15 , 0.2, 0.25]

# Lists to store centrality differences
degree_differences = []
betweenness_differences = []
closeness_differences = []
eigenvector_differences = []


# Iterate over different removal percentages
for percent in removal_percentages:
    # To make a copy of the original network
    G_copy = G.copy()

    # Remove nodes
    remove_random_nodes(G_copy, percent)

    # Calculate centrality measures before removal
    degree_centrality_before = nx.degree_centrality(G)
    betweenness_centrality_before = nx.betweenness_centrality(G)
    closeness_centrality_before = nx.closeness_centrality(G)
    eigenvector_centrality_before = nx.eigenvector_centrality(G)

    # Calculate centrality measures after removal
    degree_centrality_after = nx.degree_centrality(G_copy)
    betweenness_centrality_after = nx.betweenness_centrality(G_copy)
    closeness_centrality_after = nx.closeness_centrality(G_copy)
    eigenvector_centrality_after = nx.eigenvector_centrality(G_copy)

    # To Compute the Absolute difference of centrality measures after removal
    degree_difference = {node: abs(degree_centrality_before[node] - degree_centrality_after[node]) for node in G_copy.nodes()}
    betweenness_difference = {node: abs(betweenness_centrality_before[node] - betweenness_centrality_after[node]) for node in G_copy.nodes()}
    closeness_difference = {node: abs(closeness_centrality_before[node] - closeness_centrality_after[node]) for node in G_copy.nodes()}
    eigenvector_difference = {node: abs(eigenvector_centrality_before[node] - eigenvector_centrality_after[node]) for node in G_copy.nodes()}

    # Append centrality differences after removal to their respective lists
    degree_differences.append(list(degree_difference.values()))
    betweenness_differences.append(list(betweenness_difference.values()))
    closeness_differences.append(list(closeness_difference.values()))
    eigenvector_differences.append(list(eigenvector_difference.values()))


#Create subplots for node & edge removal
plt.figure(figsize=(8, 8))

plt.subplot(2, 2, 1)
plt.boxplot(degree_differences)
plt.xlabel('Node Removal Percentage')
plt.ylabel('Degree Centrality Difference')
plt.xticks(range(1, len(removal_percentages) + 1), [str(p) for p in removal_percentages])

plt.subplot(2, 2, 2)
plt.boxplot(betweenness_differences)
plt.xlabel('Node Removal Percentage')
plt.ylabel('Betweenness Centrality Difference')
plt.xticks(range(1, len(removal_percentages) + 1), [str(p) for p in removal_percentages])

plt.subplot(2, 2, 3)
plt.boxplot(closeness_differences)
plt.xlabel('Node Removal Percentage')
plt.ylabel('Closeness Centrality Difference')
plt.xticks(range(1, len(removal_percentages) + 1), [str(p) for p in removal_percentages])

plt.subplot(2, 2, 4)
plt.boxplot(eigenvector_differences)
plt.xlabel('Node Removal Percentage')
plt.ylabel('Eigenvector Centrality Difference')
plt.xticks(range(1, len(removal_percentages) + 1), [str(p) for p in removal_percentages])

plt.suptitle('Centrality Differences in a small-world network after Random node Removal')
plt.tight_layout()
# To save the figure as a PDF
plt.savefig("small_world_network_random_node_removal.pdf", format="pdf")

from google.colab import files
files.download("/content/small_world_network_random_node_removal.pdf")
plt.show()

# %%
# Random Edge Removal
# Random Network
import networkx as nx
import matplotlib.pyplot as plt
import random

# Function to remove random edges
def remove_random_edges(G, percent_edges):
    num_edges = int(G.number_of_edges() * percent_edges)
    edges_to_remove = random.sample(list(G.edges()), num_edges)
    G.remove_edges_from(edges_to_remove)


# Generate a random network
G = nx.erdos_renyi_graph(n=100, p=0.2, seed =1)

# Removal percentages
removal_percentages = [0.05, 0.1, 0.15, 0.2, 0.25]

# Lists to store centrality differences
degree_differences = []
betweenness_differences = []
closeness_differences = []
eigenvector_differences = []

# Iterate over different removal percentages
for percent in removal_percentages:
    # To make a copy of the original network
    G_copy = G.copy()

    # Remove random edges
    remove_random_edges(G_copy, percent)

    # Calculate centrality measures before removal
    degree_centrality_before = nx.degree_centrality(G)
    betweenness_centrality_before = nx.betweenness_centrality(G)
    closeness_centrality_before = nx.closeness_centrality(G)
    eigenvector_centrality_before = nx.eigenvector_centrality(G)

    # Calculate centrality measures after removal
    degree_centrality_after = nx.degree_centrality(G_copy)
    betweenness_centrality_after = nx.betweenness_centrality(G_copy)
    closeness_centrality_after = nx.closeness_centrality(G_copy)
    eigenvector_centrality_after = nx.eigenvector_centrality(G_copy)

    # To Compute the Absolute difference of centrality measures after removal
    degree_difference = {node: abs(degree_centrality_before[node] - degree_centrality_after[node]) for node in G_copy.nodes()}
    betweenness_difference = {node: abs(betweenness_centrality_before[node] - betweenness_centrality_after[node]) for node in G_copy.nodes()}
    closeness_difference = {node: abs(closeness_centrality_before[node] - closeness_centrality_after[node]) for node in G_copy.nodes()}
    eigenvector_difference = {node: abs(eigenvector_centrality_before[node] - eigenvector_centrality_after[node]) for node in G_copy.nodes()}

    # Append centrality differences after removal to their respective lists
    degree_differences.append(list(degree_difference.values()))
    betweenness_differences.append(list(betweenness_difference.values()))
    closeness_differences.append(list(closeness_difference.values()))
    eigenvector_differences.append(list(eigenvector_difference.values()))

# Create subplots for edge removal
plt.figure(figsize=(8, 8))

plt.subplot(2, 2, 1)
plt.boxplot(degree_differences)
plt.xlabel('Edge Removal Percentage')
plt.ylabel('Degree Centrality Difference')
plt.xticks(range(1, len(removal_percentages) + 1), [str(p) for p in removal_percentages])

plt.subplot(2, 2, 2)
plt.boxplot(betweenness_differences)
plt.xlabel('Edge Removal Percentage')
plt.ylabel('Betweenness Centrality Difference')
plt.xticks(range(1, len(removal_percentages) + 1), [str(p) for p in removal_percentages])

plt.subplot(2, 2, 3)
plt.boxplot(closeness_differences)
plt.xlabel('Edge Removal Percentage')
plt.ylabel('Closeness Centrality Difference')
plt.xticks(range(1, len(removal_percentages) + 1), [str(p) for p in removal_percentages])

plt.subplot(2, 2, 4)
plt.boxplot(eigenvector_differences)
plt.xlabel('Edge Removal Percentage')
plt.ylabel('Eigenvector Centrality Difference')
plt.xticks(range(1, len(removal_percentages) + 1), [str(p) for p in removal_percentages])

plt.suptitle('Centrality Differences in a random network after Random Edge Removal')
plt.tight_layout()
# To save the figure as a PDF
plt.savefig("random_network_random_edge_removal.pdf", format="pdf")

from google.colab import files
files.download("/content/random_network_random_edge_removal.pdf")
plt.show()

# %%
# Random Edge removal
# Scale-free Network
import networkx as nx
import matplotlib.pyplot as plt
import random

# Function to remove random edges
def remove_random_edges(G, percent_edges):
    num_edges = int(G.number_of_edges() * percent_edges)
    edges_to_remove = random.sample(list(G.edges()), num_edges)
    G.remove_edges_from(edges_to_remove)

# Create a scale-free network
G = nx.barabasi_albert_graph(n = 100, m = 2, seed=1)

# List of edge removal percentages
removal_percentages = [0.05, 0.1, 0.15, 0.2, 0.25]

# Lists to store centrality differences
degree_differences = []
betweenness_differences = []
closeness_differences = []
eigenvector_differences = []

# Iterate over different removal percentages
for percent in removal_percentages:
    # To make a copy of the original network
    G_copy = G.copy()

    # Remove random edges
    remove_random_edges(G_copy, percent)

   # Calculate centrality measures before removal
    degree_centrality_before = nx.degree_centrality(G)
    betweenness_centrality_before = nx.betweenness_centrality(G)
    closeness_centrality_before = nx.closeness_centrality(G)
    eigenvector_centrality_before = nx.eigenvector_centrality(G)

    # Calculate centrality measures after removal
    degree_centrality_after = nx.degree_centrality(G_copy)
    betweenness_centrality_after = nx.betweenness_centrality(G_copy)
    closeness_centrality_after = nx.closeness_centrality(G_copy)
    eigenvector_centrality_after = nx.eigenvector_centrality(G_copy)

    # To Compute the Absolute difference of centrality measures after removal
    degree_difference = {node: abs(degree_centrality_before[node] - degree_centrality_after[node]) for node in G_copy.nodes()}
    betweenness_difference = {node: abs(betweenness_centrality_before[node] - betweenness_centrality_after[node]) for node in G_copy.nodes()}
    closeness_difference = {node: abs(closeness_centrality_before[node] - closeness_centrality_after[node]) for node in G_copy.nodes()}
    eigenvector_difference = {node: abs(eigenvector_centrality_before[node] - eigenvector_centrality_after[node]) for node in G_copy.nodes()}

    # Append centrality differences after removal to their respective lists
    degree_differences.append(list(degree_difference.values()))
    betweenness_differences.append(list(betweenness_difference.values()))
    closeness_differences.append(list(closeness_difference.values()))
    eigenvector_differences.append(list(eigenvector_difference.values()))

# Create subplots for edge removal
plt.figure(figsize=(8, 8))

plt.subplot(2, 2, 1)
plt.boxplot(degree_differences)
plt.xlabel('Edge Removal Percentage')
plt.ylabel('Degree Centrality Difference')
plt.xticks(range(1, len(removal_percentages) + 1), [str(p) for p in removal_percentages])

plt.subplot(2, 2, 2)
plt.boxplot(betweenness_differences)
plt.xlabel('Edge Removal Percentage')
plt.ylabel('Betweenness Centrality Difference')
plt.xticks(range(1, len(removal_percentages) + 1), [str(p) for p in removal_percentages])

plt.subplot(2, 2, 3)
plt.boxplot(closeness_differences)
plt.xlabel('Edge Removal Percentage')
plt.ylabel('Closeness Centrality Difference')
plt.xticks(range(1, len(removal_percentages) + 1), [str(p) for p in removal_percentages])

plt.subplot(2, 2, 4)
plt.boxplot(eigenvector_differences)
plt.xlabel('Edge Removal Percentage')
plt.ylabel('Eigenvector Centrality Difference')
plt.xticks(range(1, len(removal_percentages) + 1), [str(p) for p in removal_percentages])

plt.suptitle('Centrality Differences in a Scale-Free Network after Random Edge Removal')
plt.tight_layout()
# To save the figure as a PDF
plt.savefig("scale_free_network_random_edge_removal.pdf", format="pdf")

from google.colab import files
files.download("/content/scale_free_network_random_edge_removal.pdf")
plt.show()

# %%
# Random edge removal
# Small-World Network
import networkx as nx
import matplotlib.pyplot as plt
import random

# Function to remove random edges
def remove_random_edges(G, percent_edges):
    num_edges = int(G.number_of_edges() * percent_edges)
    edges_to_remove = random.sample(list(G.edges()), num_edges)
    G.remove_edges_from(edges_to_remove)

# Small-world network
G = nx.watts_strogatz_graph(n =100, k = 4, p =0.2,seed =1)

# Removal percentages
removal_percentages = [0.05, 0.1, 0.15, 0.2, 0.25]

# Lists to store centrality differences
degree_differences = []
betweenness_differences = []
closeness_differences = []
eigenvector_differences = []

# Iterate over different removal percentages
for percent in removal_percentages:
    # To make a copy of the original network
    G_copy = G.copy()

    # Remove random edges
    remove_random_edges(G_copy, percent)

    # Calculate centrality measures before removal
    degree_centrality_before = nx.degree_centrality(G)
    betweenness_centrality_before = nx.betweenness_centrality(G)
    closeness_centrality_before = nx.closeness_centrality(G)
    eigenvector_centrality_before = nx.eigenvector_centrality(G)

    # Calculate centrality measures after removal
    degree_centrality_after = nx.degree_centrality(G_copy)
    betweenness_centrality_after = nx.betweenness_centrality(G_copy)
    closeness_centrality_after = nx.closeness_centrality(G_copy)
    eigenvector_centrality_after = nx.eigenvector_centrality(G_copy)

    # To Compute the Absolute difference of centrality measures after removal
    degree_difference = {node: abs(degree_centrality_before[node] - degree_centrality_after[node]) for node in G_copy.nodes()}
    betweenness_difference = {node: abs(betweenness_centrality_before[node] - betweenness_centrality_after[node]) for node in G_copy.nodes()}
    closeness_difference = {node: abs(closeness_centrality_before[node] - closeness_centrality_after[node]) for node in G_copy.nodes()}
    eigenvector_difference = {node: abs(eigenvector_centrality_before[node] - eigenvector_centrality_after[node]) for node in G_copy.nodes()}

    # Append centrality differences after removal to their respective lists
    degree_differences.append(list(degree_difference.values()))
    betweenness_differences.append(list(betweenness_difference.values()))
    closeness_differences.append(list(closeness_difference.values()))
    eigenvector_differences.append(list(eigenvector_difference.values()))

# Create subplots for edge removal
plt.figure(figsize=(8, 8))

plt.subplot(2, 2, 1)
plt.boxplot(degree_differences)
plt.xlabel('Edge Removal Percentage')
plt.ylabel('Degree Centrality Difference')
plt.xticks(range(1, len(removal_percentages) + 1), [str(p) for p in removal_percentages])

plt.subplot(2, 2, 2)
plt.boxplot(betweenness_differences)
plt.xlabel('Edge Removal Percentage')
plt.ylabel('Betweenness Centrality Difference')
plt.xticks(range(1, len(removal_percentages) + 1), [str(p) for p in removal_percentages])

plt.subplot(2, 2, 3)
plt.boxplot(closeness_differences)
plt.xlabel('Edge Removal Percentage')
plt.ylabel('Closeness Centrality Difference')
plt.xticks(range(1, len(removal_percentages) + 1), [str(p) for p in removal_percentages])

plt.subplot(2, 2, 4)
plt.boxplot(eigenvector_differences)
plt.xlabel('Edge Removal Percentage')
plt.ylabel('Eigenvector Centrality Difference')
plt.xticks(range(1, len(removal_percentages) + 1), [str(p) for p in removal_percentages])

plt.suptitle('Centrality Differences in a Small-World Network after Random Edge Removal')
plt.tight_layout()
# To save the figure as a PDF
plt.savefig("small_world_network_random_edge_removal.pdf", format="pdf")

from google.colab import files
files.download("/content/small_world_network_random_edge_removal.pdf")
plt.show()
